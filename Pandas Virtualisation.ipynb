# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df11=pd.read_csv('ACL_Export.csv')

# %%
df11.head()
# Out:
#     amount    DueDate InvoiceDate      no     ref type        day  \
# 0  -474.70  9/13/2020   8/14/2020  795401  205605   CN     Sunday
# 1   225.87  11/8/2020   10/9/2020  795401  206300   IN     Monday
# 2   180.92  2/28/2020   1/29/2020  795401  207137   IN    Tuesday
# 3  1610.87  3/12/2020   2/11/2020  516372  211206   IN  Wednesday
# 4 -1298.43  3/12/2020   4/24/2020  516372  211206   TR   Thursday
#
#    total bills agree
# 0         1000   yes
# 1         1000    no
# 2         1000    no
# 3         1000    no
# 4         1000    no

# %%
df11['amount'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
#pandas plot
df11['amount'].plot(kind='hist',bins=60)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df11['amount'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2=pd.read_csv('Book1.csv')

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977681
# 2  0.780504  0.008948  0.557808  0.797551
# 3  0.672762  0.247870  0.264071  0.444358

# %%
#Area of the values
df2.plot.area(alpha=0.4)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# %%
df2.plot.bar(stacked=True)
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0)

# %%
df11.head()
# Out:
#     amount    DueDate InvoiceDate      no     ref type        day  \
# 0  -474.70  9/13/2020   8/14/2020  795401  205605   CN     Sunday
# 1   225.87  11/8/2020   10/9/2020  795401  206300   IN     Monday
# 2   180.92  2/28/2020   1/29/2020  795401  207137   IN    Tuesday
# 3  1610.87  3/12/2020   2/11/2020  516372  211206   IN  Wednesday
# 4 -1298.43  3/12/2020   4/24/2020  516372  211206   TR   Thursday
#
#    total bills agree
# 0         1000   yes
# 1         1000    no
# 2         1000    no
# 3         1000    no
# 4         1000    no

# %%
df11.plot.line(x='DueDate',y='amount',figsize=(12,6),lw=1)
#df11.plot.line(x=df11.index,y='amount')
plt.tight_layout()

# %%
df4=pd.DataFrame(np.random.randn(1000,3),columns=['a','b','c'])

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       1000 non-null   float64
#  1   b       1000 non-null   float64
#  2   c       1000 non-null   float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %%
df4.plot.scatter(x='a',y='b',c=df4['c'],cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
#The hex size get darker as there are more points in it
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# kernel density on the entire dataframe
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#PANDAS BUILT IN VIRTUALISATION EXCERCISE AND SOLUTION

# %%
df5=pd.DataFrame(np.random.randn(500,4),columns=['a','b','c','d'])

# %%
df5.head()
# Out:
#           a         b         c         d
# 0  0.074401 -0.957210 -0.756654 -0.598595
# 1  1.214152 -0.320544 -0.543334 -0.232587
# 2  0.433983  0.481825 -0.946607 -0.408693
# 3  0.265977 -1.238831 -1.429404  0.813071
# 4  0.270009 -0.440005 -0.378664  0.554246

# %%
import seaborn as sns
df5.plot.scatter(x='a',y='b',s=50,c='red',figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
#it can also be df5['a'].hist()
df5['a'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('ggplot')

# %%
df5['a'].plot.hist(bins=20,alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df5[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df5['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df5['d'].plot.kde(lw=5,ls='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2[0:30].plot.area(alpha=0.5)
plt.legend(bbox_to_anchor=(1.0,0.5), loc='center left', borderaxespad=0)

#in other ide 
f=plt.figure()
df2[0:30].plot.area(alpha=0.5)
plt.legend(bbox_to_anchor=(1.0,0.5),loc='center left')
plt.show()
